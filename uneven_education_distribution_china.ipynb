# %%
import pandas as pd 
df = pd.read_excel(r'D:\bacon seed\scu\Zeronnn\college_data.xls')
df.head()
# Out:
#        name site   title type   belong nature              website
# 0      北京大学   北京  211985   综合      教育部     本科       www.pku.edu.cn
# 1    中国人民大学   北京  211985   综合      教育部     本科       www.ruc.edu.cn
# 2      清华大学   北京  211985   工科      教育部     本科  www.tsinghua.edu.cn
# 3  北京航空航天大学   北京  211985   工科  工业与信息化部     本科      www.buaa.edu.cn
# 4    北京理工大学   北京  211985   工科  工业与信息化部     本科       www.bit.edu.cn

# %%
df_new = df.drop_duplicates(subset = ['name'])   # 剔除重复的数据
df_site = df_new[df_new['site']!='——']
df_site = df_site[df_site['site']!='------']

# %%
# 高校总数量分析
site_counts = df_site['site'].value_counts()    #  Series 时序
dict_site = {'name': site_counts.index, 'counts':site_counts.values}   # 字典
data = pd.DataFrame(dict_site)   # 转换DataFrame格式

# %%
# 各城市高校数量
from pyecharts.charts import Bar
from pyecharts import options as opts
from pyecharts.commons.utils import JsCode


bar = Bar()
bar.add_xaxis(data['name'].values.tolist())
bar.add_yaxis("", data['counts'].values.tolist())
bar.set_global_opts(
    xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
    title_opts=opts.TitleOpts(title="各城市高校数量", subtitle="仅仅统计数量"),
    datazoom_opts=opts.DataZoomOpts(),
)
bar.set_series_opts(itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(0, 244, 255, 1)'
                }, {
                    offset: 1,
                    color: 'rgba(0, 77, 167, 1)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(0, 160, 221)',
            }})

# %%
site_counts
# Out:
# 江苏     136
# 山东     133
# 湖北     118
# 广东     116
# 湖南     107
# 河北     104
# 辽宁     100
# 河南     100
# 陕西      95
# 安徽      94
# 北京      91
# 浙江      90
# 四川      87
# 江西      83
# 黑龙江     81
# 福建      71
# 山西      68
# 上海      66
# 广西      63
# 天津      60
# 吉林      55
# 云南      50
# 重庆      49
# 贵州      45
# 新疆      38
# 甘肃      38
# 内蒙古     31
# 海南      15
# 宁夏      13
# 青海       9
# 香港       8
# 西藏       5
# 澳门       2
# Name: site, dtype: int64

# %%
from pyecharts.charts import Pie

pie = Pie()
pie.add("", [list(z) for z in zip(data['name'].values.tolist()[:10], data['counts'].values.tolist()[:10])],
       radius=["30%", "75%"],
            center=["40%", "50%"],
            rosetype="radius")
pie.set_global_opts(
            title_opts=opts.TitleOpts(title="高校数量前十名"),
            legend_opts=opts.LegendOpts(
                type_="scroll", pos_left="80%", orient="vertical"
            ),
        )  
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="097fdd130edf49d1a93857c05fab41f0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_097fdd130edf49d1a93857c05fab41f0 = echarts.init(
#                     document.getElementById('097fdd130edf49d1a93857c05fab41f0'), 'white', {renderer: 'canvas'});
#                 var option_097fdd130edf49d1a93857c05fab41f0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 136
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 133
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 118
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 116
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 107
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 104
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 95
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 94
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "40%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6c5f\u82cf",
#                 "\u5c71\u4e1c",
#                 "\u6e56\u5317",
#                 "\u5e7f\u4e1c",
#                 "\u6e56\u5357",
#                 "\u6cb3\u5317",
#                 "\u8fbd\u5b81",
#                 "\u6cb3\u5357",
#                 "\u9655\u897f",
#                 "\u5b89\u5fbd"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "80%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u9ad8\u6821\u6570\u91cf\u524d\u5341\u540d",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_097fdd130edf49d1a93857c05fab41f0.setOption(option_097fdd130edf49d1a93857c05fab41f0);
#         });
#     </script>

# %%
pie = Pie()
pie.add("", [list(z) for z in zip(data['name'].values.tolist()[-10:], data['counts'].values.tolist()[-10:])],
       radius=["30%", "75%"],
            center=["40%", "50%"],
            rosetype="radius")
pie.set_global_opts(
            title_opts=opts.TitleOpts(title="高校数量后十名"),
            legend_opts=opts.LegendOpts(
                type_="scroll", pos_left="80%", orient="vertical"
            ),
        )
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="20b86ede8f164dbba0c93db4f473ccbf" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_20b86ede8f164dbba0c93db4f473ccbf = echarts.init(
#                     document.getElementById('20b86ede8f164dbba0c93db4f473ccbf'), 'white', {renderer: 'canvas'});
#                 var option_20b86ede8f164dbba0c93db4f473ccbf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 2
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "40%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8d35\u5dde",
#                 "\u65b0\u7586",
#                 "\u7518\u8083",
#                 "\u5185\u8499\u53e4",
#                 "\u6d77\u5357",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u9999\u6e2f",
#                 "\u897f\u85cf",
#                 "\u6fb3\u95e8"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "80%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u9ad8\u6821\u6570\u91cf\u540e\u5341\u540d",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_20b86ede8f164dbba0c93db4f473ccbf.setOption(option_20b86ede8f164dbba0c93db4f473ccbf);
#         });
#     </script>

# %%
# 高校分布热力图
geo = Geo()
geo.add_schema(maptype="china")
geo.add("高校分布热力图", [list(z) for z in zip(data['name'].values.tolist(), data['counts'].values.tolist())],
       type_=ChartType.HEATMAP)
geo.set_global_opts(
            visualmap_opts=opts.VisualMapOpts(),
            title_opts=opts.TitleOpts(title="全国高校热力图"),
        )
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="682d9c8fa4a8438daace7789d78292f7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_682d9c8fa4a8438daace7789d78292f7 = echarts.init(
#                     document.getElementById('682d9c8fa4a8438daace7789d78292f7'), 'white', {renderer: 'canvas'});
#                 var option_682d9c8fa4a8438daace7789d78292f7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "\u9ad8\u6821\u5206\u5e03\u70ed\u529b\u56fe",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         136
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": [
#                         117.020359,
#                         36.66853,
#                         133
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": [
#                         114.341861,
#                         30.546498,
#                         118
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         116
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         107
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": [
#                         114.468664,
#                         38.037057,
#                         104
#                     ]
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": [
#                         123.42944,
#                         41.835441,
#                         100
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": [
#                         113.753602,
#                         34.765515,
#                         100
#                     ]
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": [
#                         108.954239,
#                         34.265472,
#                         95
#                     ]
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": [
#                         117.284922,
#                         31.861184,
#                         94
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         91
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         90
#                     ]
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": [
#                         104.075931,
#                         30.651651,
#                         87
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         83
#                     ]
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": [
#                         126.661669,
#                         45.742347,
#                         81
#                     ]
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": [
#                         119.295144,
#                         26.100779,
#                         71
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": [
#                         112.562398,
#                         37.873531,
#                         68
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         66
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": [
#                         108.327546,
#                         22.815478,
#                         63
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         60
#                     ]
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": [
#                         125.32599,
#                         43.896536,
#                         55
#                     ]
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": [
#                         102.710002,
#                         25.045806,
#                         50
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         49
#                     ]
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": [
#                         106.70741,
#                         26.598194,
#                         45
#                     ]
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": [
#                         87.627704,
#                         43.793026,
#                         38
#                     ]
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": [
#                         103.826308,
#                         36.059421,
#                         38
#                     ]
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": [
#                         111.765617,
#                         40.817498,
#                         31
#                     ]
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": [
#                         110.349228,
#                         20.017377,
#                         15
#                     ]
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": [
#                         106.258754,
#                         38.471317,
#                         13

# %%
geo = Geo()
geo.add_schema(maptype="china")
geo.add("各地区高校数量段位图", [list(z) for z in zip(data['name'].values.tolist(), data['counts'].values.tolist())],
       type_=ChartType.EFFECT_SCATTER)
geo.set_global_opts(
            visualmap_opts=opts.VisualMapOpts(is_piecewise=True, max_=150),
            title_opts=opts.TitleOpts(title="各地区高校数量段位图"),
        )
geo.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="f2223af889e7411991e9de431a27e879" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_f2223af889e7411991e9de431a27e879 = echarts.init(
#                     document.getElementById('f2223af889e7411991e9de431a27e879'), 'white', {renderer: 'canvas'});
#                 var option_f2223af889e7411991e9de431a27e879 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "\u5404\u5730\u533a\u9ad8\u6821\u6570\u91cf\u6bb5\u4f4d\u56fe",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         136
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": [
#                         117.020359,
#                         36.66853,
#                         133
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": [
#                         114.341861,
#                         30.546498,
#                         118
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         116
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         107
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": [
#                         114.468664,
#                         38.037057,
#                         104
#                     ]
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": [
#                         123.42944,
#                         41.835441,
#                         100
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": [
#                         113.753602,
#                         34.765515,
#                         100
#                     ]
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": [
#                         108.954239,
#                         34.265472,
#                         95
#                     ]
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": [
#                         117.284922,
#                         31.861184,
#                         94
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         91
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         90
#                     ]
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": [
#                         104.075931,
#                         30.651651,
#                         87
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         83
#                     ]
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": [
#                         126.661669,
#                         45.742347,
#                         81
#                     ]
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": [
#                         119.295144,
#                         26.100779,
#                         71
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": [
#                         112.562398,
#                         37.873531,
#                         68
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         66
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": [
#                         108.327546,
#                         22.815478,
#                         63
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         60
#                     ]
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": [
#                         125.32599,
#                         43.896536,
#                         55
#                     ]
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": [
#                         102.710002,
#                         25.045806,
#                         50
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         49
#                     ]
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": [
#                         106.70741,
#                         26.598194,
#                         45
#                     ]
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": [
#                         87.627704,
#                         43.793026,
#                         38
#                     ]
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": [
#                         103.826308,
#                         36.059421,
#                         38
#                     ]
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": [
#                         111.765617,
#                         40.817498,
#                         31
#                     ]
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": [
#                         110.349228,
#                         20.01

# %%
df_985 = df_title[df_title['title'] == 211985]
site_counts_985 = df_985['site'].value_counts()
dict_site_985 = {'name': site_counts_985.index, 'counts': site_counts_985.values}
data_985 = pd.DataFrame(dict_site_985)
# 985高校排行
pie = Pie()
pie.add("", [list(z) for z in zip(data_985['name'].values.tolist(), data_985['counts'].values.tolist())],
       radius=["30%", "75%"],
            center=["40%", "50%"],
            rosetype="radius")
pie.set_global_opts(
            title_opts=opts.TitleOpts(title="985高校排行"),
            legend_opts=opts.LegendOpts(
                type_="scroll", pos_left="80%", orient="vertical"
            ),
        )
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e16eaa1f2a844b7a8b2b15933f356e64" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e16eaa1f2a844b7a8b2b15933f356e64 = echarts.init(
#                     document.getElementById('e16eaa1f2a844b7a8b2b15933f356e64'), 'white', {renderer: 'canvas'});
#                 var option_e16eaa1f2a844b7a8b2b15933f356e64 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "40%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u5c71\u4e1c",
#                 "\u8fbd\u5b81",
#                 "\u9655\u897f",
#                 "\u6e56\u5357",
#                 "\u5e7f\u4e1c",
#                 "\u6c5f\u82cf",
#                 "\u56db\u5ddd",
#                 "\u5929\u6d25",
#                 "\u6e56\u5317",
#                 "\u7518\u8083",
#                 "\u91cd\u5e86",
#                 "\u798f\u5efa",
#                 "\u5b89\u5fbd",
#                 "\u6d59\u6c5f",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u5409\u6797",
#                 "\u6cb3\u5317"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "80%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "985\u9ad8\u6821\u6392\u884c",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_e16eaa1f2a844b7a8b2b15933f356e64.setOption(option_e16eaa1f2a844b7a8b2b15933f356e64);
#         });
#     </script>

# %%
df_211 = df_title[df_title['title'] == 211]
site_counts_211 = df_211['site'].value_counts()
dict_site_211 = {'name': site_counts_211.index, 'counts': site_counts_211.values}
data_211 = pd.DataFrame(dict_site_211)
# 211高校排行
pie = Pie()
pie.add("", [list(z) for z in zip(data_211['name'].values.tolist(), data_211['counts'].values.tolist())],
       radius=["30%", "75%"],
            center=["40%", "50%"],
            rosetype="radius")
pie.set_global_opts(
            title_opts=opts.TitleOpts(title="211高校排行"),
            legend_opts=opts.LegendOpts(
                type_="scroll", pos_left="80%", orient="vertical"
            ),
        )
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0630ef22ab354629a7cfff8695549033" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0630ef22ab354629a7cfff8695549033 = echarts.init(
#                     document.getElementById('0630ef22ab354629a7cfff8695549033'), 'white', {renderer: 'canvas'});
#                 var option_0630ef22ab354629a7cfff8695549033 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "40%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5317\u4eac",
#                 "\u6c5f\u82cf",
#                 "\u4e0a\u6d77",
#                 "\u9655\u897f",
#                 "\u6e56\u5317",
#                 "\u6cb3\u5317",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u56db\u5ddd",
#                 "\u5e7f\u4e1c",
#                 "\u5409\u6797",
#                 "\u5b89\u5fbd",
#                 "\u65b0\u7586",
#                 "\u5929\u6d25",
#                 "\u91cd\u5e86",
#                 "\u8fbd\u5b81",
#                 "\u6cb3\u5357",
#                 "\u6e56\u5357",
#                 "\u5185\u8499\u53e4",
#                 "\u6d77\u5357",
#                 "\u5e7f\u897f",
#                 "\u5c71\u897f",
#                 "\u8d35\u5dde",
#                 "\u4e91\u5357",
#                 "\u897f\u85cf",
#                 "\u9752\u6d77",
#                 "\u5b81\u590f",
#                 "\u798f\u5efa",
#                 "\u6c5f\u897f",
#                 "\u5c71\u4e1c",
#                 "\u6d59\u6c5f"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "left": "80%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": f
